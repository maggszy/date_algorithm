# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %% [markdown]
# First group

# %%
x = np.linspace(0, 1, 100)
y1= np.power(x,0.999999)* np.log(x)
y2= np.power(10,7) * x
y3= np.power(1.000001,x) 
y4= np.square(x)
# Out:
# <ipython-input-11-b5bfa9c32666>:2: RuntimeWarning: divide by zero encountered in log
#   y1= np.power(x,0.999999)* np.log(x)
# <ipython-input-11-b5bfa9c32666>:2: RuntimeWarning: invalid value encountered in multiply
#   y1= np.power(x,0.999999)* np.log(x)

# %%
plt.plot(x,y1, label="y1")
#plt.plot(x,y2, label="y2")
plt.plot(x,y3, label="y3")
plt.plot(x,y4, label="y4")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# Second group

# %%
y5= np.power(2,100*x)
#y6= int(math.factorial(x)//(2*math.factorial(x-2)))
y7= x*np.sqrt(x)

# %%
plt.plot(x,y5, label="y5")
#plt.plot(x,y6, label="y6")
plt.plot(x,y7, label="y7")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
